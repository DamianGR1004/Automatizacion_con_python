# %% [markdown]
# # Día 3: Lectura y escritura

# %% [markdown]
# ### Objetivos:
#
# *   Leer archivos CSV y Excel con **pandas**
# *   Manipular datos cargados
# *   Exportar a excel con formato automatizado
# *   Usar **openyxl** para ajustes avanzados

# %% [markdown]
# Cada semana recibiras un archivo csv con las ventas semanales de un producto y región.
# El objetivo es automatizar el proceso

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('tienda_4.csv')

df.head()
# Out:
#               Producto Categoría del Producto     Precio  Costo de envío  \
# 0         Lavavajillas      Electrodomésticos  1084800.0         56000.0
# 1             Cama box                Muebles   473800.0         25400.0
# 2  Balón de baloncesto   Deportes y diversión    23700.0             0.0
# 3  Modelado predictivo                 Libros    57700.0          1300.0
# 4          Auriculares           Electrónicos   138900.0          5600.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      11/11/2022    Rafael Acosta          Bogotá             4
# 1      03/01/2020  Izabela de León          Cúcuta             5
# 2      25/12/2022    Maria Alfonso        Medellín             5
# 3      23/11/2021    Lucas Olivera        Medellín             3
# 4      25/04/2022   Blanca Ramirez          Bogotá             4
#
#        Método de pago  Cantidad de cuotas      lat       lon
# 0  Tarjeta de crédito                   3  4.60971 -74.08175
# 1  Tarjeta de crédito                   2  7.89391 -72.50782
# 2               Nequi                   1  6.25184 -75.56359
# 3               Nequi                   1  6.25184 -75.56359
# 4  Tarjeta de crédito                   7  4.60971 -74.08175

# %%
df.shape
# Out:
# (2358, 12)

# %%
# Vamos a crear una columna de ganacia

df['Ganancia'] = df['Precio'] - df['Costo de envío']

df.head()
# Out:
#               Producto Categoría del Producto     Precio  Costo de envío  \
# 0         Lavavajillas      Electrodomésticos  1084800.0         56000.0
# 1             Cama box                Muebles   473800.0         25400.0
# 2  Balón de baloncesto   Deportes y diversión    23700.0             0.0
# 3  Modelado predictivo                 Libros    57700.0          1300.0
# 4          Auriculares           Electrónicos   138900.0          5600.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      11/11/2022    Rafael Acosta          Bogotá             4
# 1      03/01/2020  Izabela de León          Cúcuta             5
# 2      25/12/2022    Maria Alfonso        Medellín             5
# 3      23/11/2021    Lucas Olivera        Medellín             3
# 4      25/04/2022   Blanca Ramirez          Bogotá             4
#
#        Método de pago  Cantidad de cuotas      lat       lon   Ganancia
# 0  Tarjeta de crédito                   3  4.60971 -74.08175  1028800.0
# 1  Tarjeta de crédito                   2  7.89391 -72.50782   448400.0
# 2               Nequi                   1  6.25184 -75.56359    23700.0
# 3               Nequi                   1  6.25184 -75.56359    56400.0
# 4  Tarjeta de crédito                   7  4.60971 -74.08175   133300.0

# %% [markdown]
# #### Parte 1: Agrupar las ventas por producto y región

# %%
# Agrupando las ventas por región

ventas_por_region = df.groupby('Lugar de Compra')['Ganancia'].sum()

ventas_por_region
# Out:
# Lugar de Compra
# Armenia             270000.0
# Barranquilla      32781700.0
# Bogotá           397014900.0
# Bucaramanga       24189100.0
# Cali             117832300.0
# Cartagena         23070400.0
# Cúcuta             6938000.0
# Inírida            1446700.0
# Leticia           16192200.0
# Manizales          1230400.0
# Medellín         238564700.0
# Neiva              8726300.0
# Pasto             13645200.0
# Pereira           60764300.0
# Riohacha          22409900.0
# Santa Marta       12517000.0
# Soacha             2970000.0
# Valledupar          999000.0
# Villavicencio      1496200.0
# Name: Ganancia, dtype: float64

# %%
# Vamos a destacar el top 3 de mejores regiones

top_3_regiones = ventas_por_region.nlargest(3)

top_3_regiones
# Out:
# Lugar de Compra
# Bogotá      397014900.0
# Medellín    238564700.0
# Cali        117832300.0
# Name: Ganancia, dtype: float64

# %%
# Vamos a agrupar las ventas por producto

ventas_por_producto = df.groupby('Producto')['Ganancia'].sum()

ventas_por_producto
# Out:
# Producto
# Ajedrez de madera               1011800.0
# Armario                        15550500.0
# Asistente virtual               9905200.0
# Auriculares                     3753400.0
# Auriculares con micrófono       6051700.0
# Balón de baloncesto             2325200.0
# Balón de voleibol               2226200.0
# Batería                        32726400.0
# Bicicleta                      20284100.0
# Bloques de construcción         1823000.0
# Cama box                       31194600.0
# Cama king                      35549200.0
# Carrito de control remoto       3792800.0
# Celular ABXY                   38032700.0
# Ciencia de datos con Python     1978300.0
# Cubertería                      2506600.0
# Cubo mágico 8x8                  692600.0
# Cuerda para saltar               650900.0
# Dashboards con Power BI         1856800.0
# Dinosaurio Rex                   772500.0
# Estufa                         30607900.0
# Guitarra acústica              10667200.0
# Guitarra eléctrica             24471600.0
# Impresora                      14400000.0
# Iniciando en programación       1999800.0
# Iphone 15                      91555500.0
# Juego de mesa                   8809000.0
# Kit de bancas                  11205900.0
# Lavadora de ropa               49671100.0
# Lavavajillas                   52397800.0
# Mesa de centro                  7122500.0
# Mesa de comedor                12612900.0
# Mesa de noche                  14312600.0
# Microondas                     24245700.0
# Mochila                         4039900.0
# Modelado predictivo             2945700.0
# Muñeca bebé                     2248000.0
# Olla de presión                 3228200.0
# Pandereta                       3283300.0
# Refrigerador                   71283100.0
# Secadora de ropa               40032100.0
# Set de ollas                    7131200.0
# Set de vasos                    1354400.0
# Silla de oficina               13762500.0
# Sillón                         10586400.0
# Smart TV                       78382900.0
# Smartwatch                      6395200.0
# Sofá reclinable                30396500.0
# TV LED UHD 4K                  85500000.0
# Tablet ABXY                    53671200.0
# Vaso térmico                    2053700.0
# Name: Ganancia, dtype: float64

# %%
# Top 3 mejores productos

top_3_productos = ventas_por_producto.nlargest(3)

top_3_productos
# Out:
# Producto
# Iphone 15        91555500.0
# TV LED UHD 4K    85500000.0
# Smart TV         78382900.0
# Name: Ganancia, dtype: float64

# %% [markdown]
# #### Parte 2: Crear una tabla en un Excel con la suma total por producto y región

# %%
resumen_1 = df.groupby('Producto')['Ganancia'].sum()
resumen_2 = df.groupby('Lugar de Compra')['Ganancia'].sum()

# %%
# Exportamos a Excel

with pd.ExcelWriter('ventas_por_producto_y_region.xlsx') as writer:
    resumen_1.to_excel(writer, sheet_name='Ventas por producto', index=False)
    resumen_2.to_excel(writer, sheet_name='Ventas por region', index=False)
